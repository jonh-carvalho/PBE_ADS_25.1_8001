# %% [markdown]
# # Sqlite Sql
#
# Começando por carregar o sql no notebook

# %%
#!pip install ipython-sql
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #!pip install ipython-sql
# ----> 2 get_ipython().run_line_magic('load_ext', 'sql')
#
# File f:\Apps\source\repos\25.1\PBE_25.1_8002\.venv\lib\site-packages\IPython\core\interactiveshell.py:2482, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2480     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2481 with self.builtin_trap:
# -> 2482     result = fn(*args, **kwargs)
#    2484 # The code below prevents the output from being displayed
#    2485 # when using magics with decorator @output_can_be_silenced
#    2486 # when the last Python token in the expression is a ';'.
#    2487 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File f:\Apps\source\repos\25.1\PBE_25.1_8002\.venv\lib\site-packages\IPython\core\magics\extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File f:\Apps\source\repos\25.1\PBE_25.1_8002\.venv\lib\site-packages\IPython\core\extensions.py:62, in ExtensionManager.load_extension(self, module_str)
#      55 """Load an IPython extension by its module name.
#      56
#      57 Returns the string "already loaded" if the extension is already loaded,
#      58 "no load function" if the module doesn't have a load_ipython_extension
#      59 function, or None if it succeeded.
#      60 """
#      61 try:
# ---> 62     return self._load_extension(module_str)
#      63 except ModuleNotFoundError:
#      64     if module_str in BUILTINS_EXTS:
#
# File f:\Apps\source\repos\25.1\PBE_25.1_8002\.venv\lib\site-packages\IPython\core\extensions.py:77, in ExtensionManager._load_extension(self, module_str)
#      75 with self.shell.builtin_trap:
#      76     if module_str not in sys.modules:
# ---> 77         mod = import_module(module_str)
#      78     mod = sys.modules[module_str]
#      79     if self._call_load_ipython_extension(mod):
#
# File C:\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sql'

# %%
# %sql sqlite:///contatos.db

# %%
# %%sql
#
# CREATE TABLE CLIENTES (
#     CLIENTE_ID INTEGER PRIMARY KEY,
#     NOME TEXT NOT NULL,
#     EMAIL TEXT NOT NULL UNIQUE,
#     TELEFONE TEXT NOT NULL UNIQUE
# );
# Out:
#  * sqlite:///contatos.db
# Done.
# []

# %%
# %%sql
#
# INSERT INTO CLIENTES (NOME, EMAIL, TELEFONE)
# VALUES
#     ('Leonardo' , 'leonardo@gmail.com', '9999-9999' ),
#     ('Rafael' , 'rafael@gmail.com', '9889-8998' ),
#     ('Michelangelo' , 'michelangelo@gmail.com', '9997-7999' ),
#     ('Donatello' , 'donatello@gmail.com', '9777-7779' );
# Out:
#  * sqlite:///contatos.db
# 4 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM CLIENTES
# Out:
#  * sqlite:///contatos.db
# Done.
# [(1, 'Leonardo', 'leonardo@gmail.com', '9999-9999'),
#  (2, 'Rafael', 'rafael@gmail.com', '9889-8998'),
#  (3, 'Michelangelo', 'michelangelo@gmail.com', '9997-7999'),
#  (4, 'Donatello', 'donatello@gmail.com', '9777-7779')]

# %%
# %%sql
#
# SELECT * FROM CLIENTES WHERE EMAIL = "leonardo@gmail.com"
# Out:
#  * sqlite:///contatos.db
# Done.
# [(1, 'Leonardo', 'leonardo@gmail.com', '9999-9999')]

# %%
# %%sql
#
# INSERT INTO CLIENTES (NOME, EMAIL, TELEFONE)
# VALUES ('Leonardo' , 'leo@gmail.com', '1199-991199' );
# Out:
#  * sqlite:///contatos.db
# 1 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM CLIENTES WHERE NOME = "Leonardo" AND EMAIL = 'leo@gmail.com'
# Out:
#  * sqlite:///contatos.db
# Done.
# [(5, 'Leonardo', 'leo@gmail.com', '1199-991199')]

# %%
# %%sql
#
# SELECT * FROM CLIENTES ORDER BY NOME
# Out:
#  * sqlite:///contatos.db
# Done.
# [(2, 'Rafael', 'rafael@gmail.com', '9889-8998'),
#  (3, 'Michelangelo', 'michelangelo@gmail.com', '9997-7999'),
#  (1, 'Leonardo', 'leonardo@gmail.com', '9999-9999'),
#  (5, 'Leonardo', 'leo@gmail.com', '1199-991199'),
#  (4, 'Donatello', 'donatello@gmail.com', '9777-7779')]

# %%
# %%sql
#
# SELECT DISTINCT NOME FROM CLIENTES;
# Out:
#  * sqlite:///contatos.db
# Done.
# [('Leonardo',), ('Rafael',), ('Michelangelo',), ('Donatello',)]

# %%
# %%sql
# SELECT COUNT(*) FROM clientes;
# Out:
#  * sqlite:///contatos.db
# Done.
# [(5,)]

# %%
# %%sql
#
# UPDATE clientes
# SET nome = 'Leonardo X'
# WHERE EMAIL = 'leo@gmail.com';
# Out:
#  * sqlite:///contatos.db
# 1 rows affected.
# []

# %%
# %%sql
# select * from clientes;
# Out:
#  * sqlite:///contatos.db
# Done.
# [(1, 'Leonardo', 'leonardo@gmail.com', '9999-9999'),
#  (2, 'Rafael', 'rafael@gmail.com', '9889-8998'),
#  (3, 'Michelangelo', 'michelangelo@gmail.com', '9997-7999'),
#  (4, 'Donatello', 'donatello@gmail.com', '9777-7779'),
#  (5, 'Leonardo X', 'leo@gmail.com', '1199-991199')]

# %%
# %%sql
#
# DELETE FROM clientes WHERE nome = 'Leonardo X';
# Out:
#  * sqlite:///contatos.db
# 1 rows affected.
# []

# %%
# %%sql
# select * from clientes;
# Out:
#  * sqlite:///contatos.db
# Done.
# [(1, 'Leonardo', 'leonardo@gmail.com', '9999-9999'),
#  (2, 'Rafael', 'rafael@gmail.com', '9889-8998'),
#  (3, 'Michelangelo', 'michelangelo@gmail.com', '9997-7999'),
#  (4, 'Donatello', 'donatello@gmail.com', '9777-7779'),
#  (5, 'Leonardo', 'leo@gmail.com', '1999-9999')]

# %%
# %%sql
#
# INSERT INTO clientes (nome, email, telefone)
# VALUES ('Leonardo', 'leo@gmail.com', '1999-9999')
# Out:
#  * sqlite:///contatos.db
# 1 rows affected.
# []
